# %%
import os
import pandas as pd
import json

# %% [markdown]
# ### Valentine

# %%
dataset_name = "TPC-DI"

# %%
base_path = f'../../../../../datasets/{dataset_name}/'
use_cases = ['Joinable', 'Semantically-Joinable', 'Unionable', 'View-Unionable']

# %%
unique_columns = {}

for use_case in use_cases:
    folder_path = os.path.join(base_path, use_case, 'target-tables')

    if os.path.exists(folder_path):
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.csv'):
                file_path = os.path.join(folder_path, file_name)
                try:
                    df = pd.read_csv(file_path)
                    for column in df.columns:
                        if column not in unique_columns:
                            value_counts = df[column].value_counts()
                            if len(value_counts) > 100:
                                value_counts = value_counts.head(50)
                            unique_columns[column] = value_counts.index.tolist()
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
    else:
        print(f"Folder not found: {folder_path}")
unique_columns
# Out:
# {'FisY': ['2009/2010'],
#  'SecNa': ['Democratic participation and civil society',
#   'Public sector policy and administrative management',
#   'Promotion of development awareness',
#   'Human rights',
#   'Education policy and administrative management',
#   'STD control including HIV/AIDS',
#   'Environmental policy and administrative management',
#   'Agricultural policy and administrative management',
#   'Health policy and administrative management',
#   'Business support services and institutions',
#   'Basic health care',
#   'Primary education',
#   'Teacher training',
#   'Vocational training',
#   'Basic life skills for youth and adults',
#   'Legal and judicial development',
#   'Health education',
#   'Agricultural development',
#   'Trade policy and administrative management',
#   'Higher education',
#   'Public finance management',
#   'Food crop production',
#   'Employment policy and administrative management',
#   'Environmental education/training',
# ...

# %%
file_name = f'{dataset_name.lower()}_unique_columns.json'
with open(file_name, 'w') as f:
    json.dump(unique_columns, f, indent=2)
    print(f"Unique columns saved to {file_name}")
# Out:
# Unique columns saved to tpc-di_unique_columns.json

# %% [markdown]
# ### GDC

# %%
base_path = 'gdc_unique_columns_concat_values.csv'
file_name = 'gdc_columns.json'

base_path = '/Users/pena/nyu-code/data-integration-eval/data_generation/source/opendata/miller2_horizontal_0_ec_ev_source.csv'
file_name='opendata.json'

# %%
unique_columns = {}
df = pd.read_csv(base_path)
for column in df.columns:
    value_counts = df[column].value_counts()
    if len(value_counts) > 100:
        value_counts = value_counts.head(50)
    unique_columns[column] = value_counts.index.tolist()
unique_columns
# Out:
# {'Fiscal year': ['2009/2010'],
#  'Project number': ['M012838002',
#   'M012500001',
#   'A032226001',
#   'M010431001',
#   'A032039001',
#   'M013099001',
#   'A032162001',
#   'M013123001',
#   'A032281001',
#   'M013120001',
#   'M012806001',
#   'M012294004',
#   'A033662001',
#   'A033266001',
#   'A033975001',
#   'M012955001',
#   'A031644001',
#   'A032229002',
#   'M012133001',
#   'A032668001',
#   'A031974001',
#   'A032225001',
#   'M012823001',
#   'A033735PRG',
#   'A032909003',
#   'A031635001',
#   'A033256PRE',
#   'A032569001',
#   'A032178001',
#   'A033535001',
#   'A032281PRE',
#   'A031785002',
#   'A031268001',
#   'A032884002',
#   'A031006001',
#   'A033313PRE',
#   'A031129001',
#   'M012870002',
#   'M012660001',
#   'M012870001',
#   'M012060001',
#   'A032909002',
#   'A032152PRE',
#   'A032615001',
#   'A033265PRE',
#   'A021833001',
#   'A033983PRE',
#   'A033090001',
#   'A032886001',
#   'A034866001'],
# ...

# %%
with open(file_name, 'w') as f:
    json.dump(unique_columns, f, indent=2)
    print(f"Unique columns saved to {file_name}")
# Out:
# Unique columns saved to opendata.json
